# %% [markdown]
# # what is matplotlib?

# %% [markdown]
# For the Python programming language, Matplotlib is a popular 2D charting toolkit. It gives you access to a wide range of tools for using Python to build various kinds of static, animated, and interactive visualizations. Matplotlib is a well-liked option for data visualization, scientific charting, and producing publication-quality visuals because of its user-friendly, adaptable, and highly adjustable design.
#
# Using matplotlib you can draw different graph like below:
#
# Line Plot
# Bar Chart
# Histogram
# Scatter Plot
# Pie Chart
# Area Plot
# Error Chart
# etc.

# %% [markdown]
# why do we need visualisation?
# summarisation of data
#
# matplotlib, seaborn, plotly, bokeh
#
# matplotlib:- Matplotlib is a comprehensive library for creating static, animated, and interactive visualizations in Python. Matplotlib makes easy things easy and hard things possible

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore') #suppress all the warnings

# %%
#line, scatter, bar, histogram, pie chart, box plot, violin plot

# %%
#generate random numbers in numpy
x = np.random.rand(50)

# %%
len(x)
# Out:
# 60

# %%
x
# Out:
# array([0.64851208, 0.14820488, 0.7632179 , 0.32440727, 0.61248414,
#        0.11436976, 0.72834897, 0.55436035, 0.20993821, 0.90767503,
#        0.68248683, 0.1315024 , 0.32102152, 0.64616466, 0.37232091,
#        0.37118573, 0.80574371, 0.64789744, 0.67069084, 0.91919027,
#        0.02661045, 0.11178699, 0.44418427, 0.08412631, 0.66142018,
#        0.02433294, 0.48092727, 0.86996775, 0.57509641, 0.99768423,
#        0.43614889, 0.91027307, 0.86927763, 0.51416563, 0.89005414,
#        0.85785971, 0.81255382, 0.59137359, 0.28147669, 0.33857307,
#        0.34366274, 0.76018513, 0.01373614, 0.68484145, 0.54428354,
#        0.41091032, 0.81476967, 0.59976741, 0.0343283 , 0.7561565 ,
#        0.28268889, 0.52788464, 0.79410747, 0.98804652, 0.16355451,
#        0.84481993, 0.71896977, 0.96192846, 0.97323551, 0.89682867])

# %%
df = pd.DataFrame(np.random.randn(1000), columns = ['Data'], index = pd.date_range('2024-09-08', periods = 1000))

# %%
df
# Out:
#                 Data
# 2024-09-08  1.265605
# 2024-09-09 -1.076782
# 2024-09-10  0.966172
# 2024-09-11 -1.113912
# 2024-09-12  1.242955
# ...              ...
# 2027-05-31  0.251936
# 2027-06-01  0.552098
# 2027-06-02  0.859675
# 2027-06-03 -1.844269
# 2027-06-04 -0.589088
#
# [1000 rows x 1 columns]

# %%
df.plot(figsize = (20, 8)) #summary>> most of the values are fluctuating between -2.7 and 2.7
# Out:
# <AxesSubplot: >

# %%
y = np.random.rand(50)

# %% [markdown]
# scatter plot:- A scatter plot is a type of data visualization that displays values for two variables as points on a Cartesian plane.Each point represents the value of one variable corresponding to the value of the other variable

# %%
plt.scatter(x, y)

# %% [markdown]
# line plot:-whenever you want to depict the relation between two variables in the form of trend mostly in x axis the date - time column is there

# %%
x = [1, 2, 3, 4, 5] #assume x is no of day
y = [5, 2, 7, 8, 1] #y is price of stock

# %%
plt.plot(x,y,color="orange")
plt.title("the line chart understand the syntax")
plt.xlabel("day intervals as x point")
plt.ylabel("price at ypoint")
plt.grid()
plt.show()

# %%
plt.plot(x,y,color="orange",marker="o",linestyle="--",linewidth=4,markersize=10)
plt.title("the line chart understand the syntax")
plt.xlabel("day intervals as x point")
plt.ylabel("price at ypoint")
plt.grid()
plt.show()

# %%
x = [1, 2, 3, 4, 5]
y1 = [5, 1, 7, 8, 2]
y2 = [7, 8, 3, 5, 1 ]

plt.plot(x,y1,color="y",marker="o",linestyle="--",markersize=7,linewidth=4,label="tata motor stocks")
plt.plot(x,y2,color="r",marker="o",linestyle="--",markersize=7,linewidth=4,label="tata power stocks")

plt.title("multi line in one plot")

plt.xlabel("days")
plt.ylabel("stock price")
plt.legend()
plt.show()#legend thats show in graph as tata power and tata motor stocks as a print function

# %%
x=np.linspace(0,10,100)

# %%
np.sin(x)
# Out:
# array([ 0.        ,  0.10083842,  0.20064886,  0.2984138 ,  0.39313661,
#         0.48385164,  0.56963411,  0.64960951,  0.72296256,  0.78894546,
#         0.84688556,  0.8961922 ,  0.93636273,  0.96698762,  0.98775469,
#         0.99845223,  0.99897117,  0.98930624,  0.96955595,  0.93992165,
#         0.90070545,  0.85230712,  0.79522006,  0.73002623,  0.65739025,
#         0.57805259,  0.49282204,  0.40256749,  0.30820902,  0.21070855,
#         0.11106004,  0.01027934, -0.09060615, -0.19056796, -0.28858706,
#        -0.38366419, -0.47483011, -0.56115544, -0.64176014, -0.7158225 ,
#        -0.7825875 , -0.84137452, -0.89158426, -0.93270486, -0.96431712,
#        -0.98609877, -0.99782778, -0.99938456, -0.99075324, -0.97202182,
#        -0.94338126, -0.90512352, -0.85763861, -0.80141062, -0.73701276,
#        -0.66510151, -0.58640998, -0.50174037, -0.41195583, -0.31797166,
#        -0.22074597, -0.12126992, -0.0205576 ,  0.0803643 ,  0.18046693,
# ...

# %%
plt.plot(x,np.sin(x),".-")
plt.plot(x,np.cos(x),".--")
plt.grid()

# %%
plt.plot(x,np.sin(x),":")
plt.plot(x,np.cos(x),".")
plt.grid()

# %%
plt.figure() #initialising a page to make plot
plt.subplot(1,2,1)#1st row 2 column make  horizontal and 1 is name of sub ploat
plt.plot(x,np.sin(x))

plt.subplot(1,2,2)
plt.plot(x,np.cos(x))

plt.show()

# %%
plt.figure() #initialising a page to make plot
plt.subplot(2, 1, 1)
plt.plot(x, np.sin(x))#2 row 1 column make  vertical and 1 is name of sub ploat

plt.subplot(2, 1, 2)
plt.plot(x, np.cos(x))

plt.show()

# %%
plt.figure() #initialising a page to make plot
plt.subplot(2, 2, 1)
plt.plot(x, np.tan(x))

plt.subplot(2, 2, 2)
plt.plot(x, np.cos(x))

plt.subplot(2, 2, 3)
plt.plot(x, np.sin(x))

plt.subplot(2, 2, 4)
plt.plot(x, np.sin(x+1))

plt.show()

# %%
plt.plot(x, np.sin(x-0), color = 'blue')
plt.ylim(-1.5, 1.5)
plt.xlim(1, 15)
plt.show()

# %%
plt.plot(x, np.sin(x-0), color = 'blue')
plt.ylim(-1.5, 1.5)
plt.xlim(1, 15)
plt.axis('equal')
plt.grid()
plt.show()

# %%
#histogram>> continuous numerical data

data = np.random.randn(1000) #by default 10 bins are created
plt.hist(data)
plt.show()

# %%
data = np.random.randn(1000) #by default 10 bins are created
plt.hist(data,color="r",bins=15)
plt.grid()
plt.show()

# %%
#stacked histogram >> two histograms together
data1 = np.random.normal(0, 1, 5000)
data2 = np.random.normal(3, 2, 5000)

# %%
plt.hist([data1,data2],bins=20,color=["r","b"],label=['dist1','dist2'])
plt.xlabel("values")
plt.ylabel('frequency')
plt.title("stacke histo")
plt.show()

# %%
#scatterplot >> to understand the relationship between two features
x = np.random.rand(50)
y = np.random.rand(50)

# %%
plt.scatter(x, y, c = 'r', marker = "o")
plt.show()

# %%
#bar plot >> To see the districution of categorical variables
x = ["a", "b", "c","d"] #name of students
y = [4, 6, 1, 10] #no of days present in the class

# %%
plt.bar(x,y,color="b")#vertical
# Out:
# <BarContainer object of 4 artists>

# %%
plt.barh(x,y,color="r")#horizontal
# Out:
# <BarContainer object of 4 artists>

# %%
#pie chart :-To understand the percent distribution of data
langs = ["C", "Python", "Java"]
students = [20, 100, 40]

plt.pie(students, labels = langs, autopct = "%1.1f%%")
plt.title("Pie chart")
plt.show()

# %%
#focus on one segment
explode=(0,0.1,0.1)
langs = ["C", "Python", "Java"]
students = [20, 100, 40]

plt.pie(students, labels = langs, autopct = "%1.1f%%",explode=explode,shadow=True)
plt.title("Pie chart")
plt.show()

# %%
#3d plot >> 3 dimesion plot
x = np.random.rand(20)
y = np.random.rand(20)
z = np.random.rand(20)

fig = plt.figure()
ax = fig.add_subplot(projection = '3d')
ax.scatter(x, y, z, c='red')
plt.show()

# %%
data = pd.read_csv("Bank_churn.csv")
data
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
plt.scatter(x=data['Age'],y=data['Balance'])
plt.xlabel("age")
plt.ylabel('Balance')
plt.title("bank details")
plt.grid()
plt.show()

# %%
data.plot.scatter(x = 'Age', y = 'Balance')
