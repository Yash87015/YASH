# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")

# %%
tips = sns.load_dataset('tips')

# %%
##how total bill(aggregated) varies with different day
sns.barplot(x='day',y = 'total_bill', data = tips)
# Out:
# <AxesSubplot: xlabel='day', ylabel='total_bill'>

# %%
sns.jointplot(x = tips.total_bill, y = tips.tip) #draw a plot of two variables with distribution thats also bivariate(means two plot) plots

# %% [markdown]
# joint plot:-to understand relationship also distribution of two varible

# %%
sns.jointplot(x = tips.total_bill, y = tips.tip, kind = 'reg') #reg>> regrssion line to represent relationship
#kernal dencity estimator(kde)

# %%
sns.jointplot(x = tips.total_bill, y = tips.tip, kind = 'hex')

# %%
#kernel density estimator, contour>>meterological
#contour plot use whetherforcasting and cyclone read thats type of database 
sns.jointplot(x = tips.total_bill, y = tips.tip, kind = 'kde')

# %%
tips.dtypes
# Out:
# total_bill     float64
# tip            float64
# sex           category
# smoker        category
# day           category
# time          category
# size             int64
# dtype: object

# %%
sns.pairplot(tips)
#make plots scatter plot with respect to all numerical columns

# %%
#univarient:oe feature at a time
#bivariant:-two feature at a time >> indicate bar or histo gram graph

# %%
sns.pairplot(tips, hue = 'smoker')

# %%
sns.pairplot(tips, hue = 'smoker',palette='coolwarm')

# %%
#https://seaborn.pydata.org/generated/seaborn.color_palette.html
# https://seaborn.pydata.org/tutorial/color_palettes.html

# %%
sns.color_palette("husl", 9)
# Out:
# [(0.9677975592919913, 0.44127456009157356, 0.5358103155058701),
#  (0.8369430560927636, 0.5495828952802333, 0.1952683223448124),
#  (0.6430915736746491, 0.6271955086583126, 0.19381135329796756),
#  (0.3126890019504329, 0.6928754610296064, 0.1923704830330379),
#  (0.20582072623426667, 0.6842209016721069, 0.5675558225732941),
#  (0.2151139535594307, 0.6700707833028816, 0.7112365203426209),
#  (0.23299120924703914, 0.639586552066035, 0.9260706093977744),
#  (0.731751635642941, 0.5128186367840487, 0.9581005178234921),
#  (0.9614880299080136, 0.3909885385134758, 0.8298287106954371)]

# %%
sns.color_palette("pastel")
# Out:
# [(0.6313725490196078, 0.788235294117647, 0.9568627450980393),
#  (1.0, 0.7058823529411765, 0.5098039215686274),
#  (0.5529411764705883, 0.8980392156862745, 0.6313725490196078),
#  (1.0, 0.6235294117647059, 0.6078431372549019),
#  (0.8156862745098039, 0.7333333333333333, 1.0),
#  (0.8705882352941177, 0.7333333333333333, 0.6078431372549019),
#  (0.9803921568627451, 0.6901960784313725, 0.8941176470588236),
#  (0.8117647058823529, 0.8117647058823529, 0.8117647058823529),
#  (1.0, 0.996078431372549, 0.6392156862745098),
#  (0.7254901960784313, 0.9490196078431372, 0.9411764705882353)]

# %%
sns.color_palette()
# Out:
# [(0.12156862745098039, 0.4666666666666667, 0.7058823529411765),
#  (1.0, 0.4980392156862745, 0.054901960784313725),
#  (0.17254901960784313, 0.6274509803921569, 0.17254901960784313),
#  (0.8392156862745098, 0.15294117647058825, 0.1568627450980392),
#  (0.5803921568627451, 0.403921568627451, 0.7411764705882353),
#  (0.5490196078431373, 0.33725490196078434, 0.29411764705882354),
#  (0.8901960784313725, 0.4666666666666667, 0.7607843137254902),
#  (0.4980392156862745, 0.4980392156862745, 0.4980392156862745),
#  (0.7372549019607844, 0.7411764705882353, 0.13333333333333333),
#  (0.09019607843137255, 0.7450980392156863, 0.8117647058823529)]

# %%
#boxplot using sns directly(earlier catplot)
sns.boxplot(x = 'day', y = 'total_bill', data= tips, palette = 'rainbow')
# Out:
# <AxesSubplot: xlabel='day', ylabel='total_bill'>

# %%
#boxplot using sns directly(earlier catplot)
sns.boxplot( data= tips, palette = 'rainbow',orient='h')
# Out:
# <AxesSubplot: >

# %%
df = tips[['total_bill', 'tip', 'size']]

# %%
df.corr()
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
#heatmap>> value encoded with different colours
sns.heatmap(ab.corr(), cmap = 'coolwarm', annot=True)
# Out:
# <AxesSubplot: >

# %%
df = sns.load_dataset("tips")

# %%
sns.countplot(x ="sex", data=df )
# Out:
# <AxesSubplot: xlabel='sex', ylabel='count'>

# %%
sns.lmplot(x = 'total_bill', y = 'tip', data =df)

# %%
sns.lmplot(x = 'total_bill', y = 'tip', data =df, height = 8)

# %%
sns.lmplot(x = 'total_bill', y = 'tip', data =df, height = 15, aspect =2)
